# %% [markdown]
# <h1>Calculations</h1>
# In the following I will explain some of the Calculations that can be made using Python and NumPy. And plot them using Matplotlib.

# %% [markdown]
# <h3>Basic Arithmetic Calculations</h3>
# The operators <b>‘+’, ‘*’, ‘-’</b> and <b>‘/’</b> can be used to perform basic calculations. In order from left to right they are used for addition, multiplication, subtraction and division. Division always returns a floating point number, whereas the other operators return integer values. The floating point data type (‘float’) can store decimal numbers; the integer data type can not.

# %%
print (2+2)
print (2*2)
print (2-2)
print (2/2)
# Out:
# 4
# 4
# 0
# 1.0

# %% [markdown]
# To get an integer result out of a division you can  do floor division. Floor division is performed using the ‘//’ operator. This calculation leaves a remainder that can be calculated with the ‘%’ operator.

# %%
print (5/2) # displays the usual result as float
print (5//2) # this will discard the fractional part, always rounded down
print (5%2) # this will display the remainder of the division
# Out:
# 2.5
# 2
# 1

# %% [markdown]
# When mixing floating point values and other data types; python will convert the integer to a float.

# %% [markdown]
# To calculate powers it is possible to use the ‘**’ operator.

# %%
print (3*2)
print (3**2)
# Out:
# 6
# 9

# %% [markdown]
# To assign value to a variable you can use the equal sign ‘=’. Python automatically assigns a data type to the variable that matches the value.

# %%
result = 3+3
print (result)
# Out:
# 6

# %% [markdown]
# To perform calculations on a variable you can also utilize the equal sign ‘=’.

# %%
print ('First result:', result)
result += 3 # this will add 3 to the variable 
print ('Second result:', result)
result -= 2 # this will subtract 2 again
print ('Third result:', result)
# Out:
# First result: 6
# Second result: 9
# Third result: 7

# %% [markdown]
# <h4>Calculation Order</h4>
# The order in which calculations are performed is as follows.
# <ol><li>Parentheses/Brackets'()'</li>
# <li>Indices (squareroot, power etc)</li>
# <li>Divide '/'</li>
# <li>Multiply '*'</li>
# <li>Add '+'</li>
# <li>Subtract '-'</li>
# </ol>

# %% [markdown]
# <b>Parentheses</b> <b>'()'</b>can be used to group calculations together thus changing the order the calculations are performed in.

# %%
print ((2+3)/2)
print (2+3/2)
# Out:
# 2.5
# 3.5

# %% [markdown]
# %%%add square and np.sqrt and so on (i know i did this already but where is it?)

# %% [markdown]
# <h3>Plotting Functions</h3>
# Now we will use some of the things that were explained to calculate some useful functions. Some features of Matplotlib will also be explained in the process. More on that in the designated section.

# %% [markdown]
# <h4>Square Root</h4>
# In numpy the square root is calculated with <b>np.sqrt</b>.<br>
# We will also add in a legend and a title using <b>plt.title</b> and <b>plt.legend</b>.

# %%
x = np.linspace(0, 10, 100) 

y = np.sqrt(x)

plt.plot(x, y, label='y = sqrt(x)') # the label is declared here for the legend
plt.xlabel('x') # label for the x axis
plt.ylabel('y') # label for the y axis
plt.title('Square Root Function') 
plt.legend() 
plt.grid()  
plt.show()

# %% [markdown]
# <h4>Exponential Function</h4>
# The exponential function is calculated with "np.exp"

# %%
x = np.linspace(-2, 2, 100) 

# exponential function (y = e^x)
y = np.exp(x)

plt.plot(x, y, label='y = e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Exponential Function')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h4>Natural Logarithmic Function</h4>
# The natural logarithmic function can be plottet using <b>np.log</b>.

# %%
x = np.linspace(0.01, 2, 100)  

y = np.log(x)

plt.plot(x, y, label='y = ln(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Natural Logarithm Function: y = ln(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h4>Sine</h4>
# The natural sine function can be plottet using <b>np.sin</b>.

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Sine Function')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid()
plt.show()

# %% [markdown]
# <h4>Cosine</h4>
# To plot the cosine function <b>np.cos</b> is used.

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.cos(x)

plt.plot(x, y)
plt.title('Cosine Function')
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.grid()
plt.show()

# %% [markdown]
# <h4>Tangent</h4>
# To plot the tangent function <b>np.tan</b> is used.

# %%
x = np.linspace(-np.pi/2+0.01, np.pi/2 - 0.01, 100) #the function becomes infinite at -pi/2 and pi/2, these points are excluded here
y = np.tan(x)

# Plot the tangent function
plt.plot(x, y)
plt.title('Tangent Function')
plt.xlabel('x')
plt.ylabel('tan(x)')
plt.grid()
plt.show()

# %% [markdown]
# <h4>Cotangent</h4>
# Since <b>np.cot</b> does not exist we just use <b>1/np.tan</b>. As the cotangent is just the inverse of the tangent.

# %%
x = np.linspace(0.01, np.pi-0.01, 100) 
y = 1/np.tan(x)

# Plot the cotangent function
plt.plot(x, y)
plt.title('Cotangent Function')
plt.xlabel('x')
plt.ylabel('cot(x)')
plt.grid()
plt.show()

# %% [markdown]
# <h4>Arccosine</h4>
# To plot the arccosine "acos" we'll use <b>np.arccos</b>.

# %%
x = np.linspace(-1, 1, 100)
y = np.arccos(x)

plt.plot(x, y)
plt.title('arccos')
plt.xlabel('x')
plt.ylabel('arccos(x)')
plt.grid()
plt.show()

# %% [markdown]
# <h4>Arcsine</h4>
# To plot the arcsine "asin" we'll use <b>np.arcsin</b>.

# %%
x = np.linspace(-1, 1, 100)
y = np.arcsin(x)

plt.plot(x, y)
plt.title('arcsine')
plt.xlabel('x')
plt.ylabel('arcsin(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# <h4>Arctan</h4>
# To plot the arctan "atan" we'll use <b>np.arctan</b>.

# %%
x = np.linspace(-5, 5, 100)
y = np.arctan(x)

plt.plot(x, y)
plt.title('arctangent')
plt.xlabel('x')
plt.ylabel('arctan(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# <h4>Sinc</h4>
# Sinc is just "sin(x)/x" so we'll plot that

# %%
x = np.linspace(-10, 10, 1000)
y = np.sin(x)/x


plt.plot(x, y)
plt.title('sinc')
plt.xlabel('x')
plt.ylabel('sinc(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# <h4>Hyperbolic Sine Function</h4>
# The hyperbolic sine function sinh is plotted by using <b>np.sinh</b>.

# %%
x = np.linspace(-5, 5, 100)
y = np.sinh(x)

plt.plot(x, y)
plt.title('sinh')
plt.xlabel('x')
plt.ylabel('sinh(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# <h4>Tanh</h4>
# The tanh is plotted using <b>np.tanh</b>.

# %%
x = np.linspace(-5, 5, 100)
y = np.tanh(x)

plt.plot(x, y)
plt.title('tanh')
plt.xlabel('x')
plt.ylabel('tanh(x)')
plt.grid(True)
plt.show()
